# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('benign.csv', delimiter=",")

# %%
df2 = pd.read_csv('malware.csv', delimiter=",")

# %%
#Concatenating the dataframes into one 
final = pd.concat([df1, df2]).reset_index(drop=True)
final.head()
# Out:
#                                                  url  use_of_ip  abnormal_url  \
# 0  http://1337x.to/torrent/1048648/American-Snipe...          0             1
# 1  http://1337x.to/torrent/1110018/Blackhat-2015-...          0             1
# 2  http://1337x.to/torrent/1122940/Blackhat-2015-...          0             1
# 3  http://1337x.to/torrent/1124395/Fast-and-Furio...          0             1
# 4  http://1337x.to/torrent/1145504/Avengers-Age-o...          0             1
#
#    count.  count-www  count@  count_dir  count_embed_domian  short_url  \
# 0       1          0       0          4                   0          0
# 1       1          0       0          4                   0          0
# 2       1          0       0          4                   0          0
# 3       1          0       0          4                   0          0
# 4       1          0       0          4                   0          0
#
# ...

# %%
final.tail()
# Out:
#                                                      url  use_of_ip  \
# 46939  http://www.plastischechirurgie.net/gesicht/fac...          0
# 46940  http://www.plastischechirurgie.net/haartranspl...          0
# 46941  http://www.plastischechirurgie.net/korper/gyna...          0
# 46942  http://dl.get1993desk.com/n/50517366/RealPlaye...          0
# 46943  http://fb.com.accounts.login.userid.492739.fbs...          0
#
#        abnormal_url  count.  count-www  count@  count_dir  count_embed_domian  \
# 46939             1       2          1       0          2                   0
# 46940             1       2          1       0          1                   0
# 46941             1       2          1       0          2                   0
# 46942             1       3          0       0          3                   0
# 46943             1       7          0       0          0                   0
#
#        short_url  count-https  ...  count=  url_length  hostname_length  \
# ...

# %%
final.shape
# Out:
# (46944, 24)

# %%
# Storing the data in CSV file
final.to_csv('final.csv', index=False)
